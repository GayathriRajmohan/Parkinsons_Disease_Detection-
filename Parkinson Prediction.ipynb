# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/parkinsons.csv')

# %%
df
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
df.nunique()
# Out:
# name                195
# MDVP:Fo(Hz)         195
# MDVP:Fhi(Hz)        195
# MDVP:Flo(Hz)        195
# MDVP:Jitter(%)      173
# MDVP:Jitter(Abs)     19
# MDVP:RAP            155
# MDVP:PPQ            165
# Jitter:DDP          180
# MDVP:Shimmer        188
# MDVP:Shimmer(dB)    149
# Shimmer:APQ3        184
# Shimmer:APQ5        189
# MDVP:APQ            189
# Shimmer:DDA         189
# NHR                 185
# HNR                 195
# status                2
# RPDE                195
# DFA                 195
# spread1             195
# spread2             194
# D2                  195
# PPE                 195
# dtype: int64

# %%
sns.kdeplot(df['MDVP:Fo(Hz)'], fill=True, color='blue', alpha=0.7)

plt.xlabel('Age')
plt.ylabel('Density')
plt.title('KDE Plot of Age')

plt.show()

# %%
sns.kdeplot(df['MDVP:Fhi(Hz)'], fill=True, color='blue', alpha=0.7)

plt.xlabel('Age')
plt.ylabel('Density')
plt.title('KDE Plot of Age')

plt.show()

# %%
sns.kdeplot(df['MDVP:Flo(Hz)'], fill=True, color='blue', alpha=0.7)

plt.xlabel('Age')
plt.ylabel('Density')
plt.title('KDE Plot of Age')

plt.show()

# %%
df.status.value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
df.status.hist()
# Out:
# <Axes: >

# %%
df=df.drop('name',axis=1)

# %%
df.hist(figsize=(25,30))
plt.show()

# %%
df.corr()
# Out:
#                   MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# MDVP:Fo(Hz)          1.000000      0.400985      0.596546       -0.118003
# MDVP:Fhi(Hz)         0.400985      1.000000      0.084951        0.102086
# MDVP:Flo(Hz)         0.596546      0.084951      1.000000       -0.139919
# MDVP:Jitter(%)      -0.118003      0.102086     -0.139919        1.000000
# MDVP:Jitter(Abs)    -0.382027     -0.029198     -0.277815        0.935714
# MDVP:RAP            -0.076194      0.097177     -0.100519        0.990276
# MDVP:PPQ            -0.112165      0.091126     -0.095828        0.974256
# Jitter:DDP          -0.076213      0.097150     -0.100488        0.990276
# MDVP:Shimmer        -0.098374      0.002281     -0.144543        0.769063
# MDVP:Shimmer(dB)    -0.073742      0.043465     -0.119089        0.804289
# Shimmer:APQ3        -0.094717     -0.003743     -0.150747        0.746625
# Shimmer:APQ5        -0.070682     -0.009997     -0.101095        0.725561
# ...

# %%
r, p = stats.pearsonr(df.status, df.PPE)

# %%
r,p
# Out:
# (0.5310391538731205, 1.3926186153164091e-15)

# %%
sns.heatmap(df.drop('status',axis=1).corr(),annot=False,cmap='PuBuGn')
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import svm

# %%
scaler = StandardScaler()
x = df.drop(['status'],axis=1)
y = df['status']

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,shuffle=True)
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
model1 = svm.SVC(kernel='rbf', gamma=1, C=10)

# %%
model1.fit(X_train, y_train)
# Out:
# SVC(C=10, gamma=1)

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
y_pred = model1.predict(X_test)
test_data_accuracy = accuracy_score(y_test, y_pred)

# %%
test_data_accuracy*100
# Out:
# 85.71428571428571

# %%
model2=LogisticRegression()

# %%
model2.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model2.predict(X_test)
test_data_accuracy = accuracy_score(y_test, y_pred)
test_data_accuracy*100
# Out:
# 83.6734693877551
